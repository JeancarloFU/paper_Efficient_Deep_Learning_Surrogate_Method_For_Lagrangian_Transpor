# %%
#---copy this notebook in your Google Drive---
#
import os
#create a temporal mount point (just for running this script)
mount_point='/content/gdrive/'
from google.colab import drive
drive.mount(mount_point)
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
os.listdir(mount_point)  #check the name of My google Drive:
# Out:
# ['Othercomputers',
#  '.file-revisions-by-id',
#  'MyDrive',
#  '.shortcut-targets-by-id',
#  '.Trash-0',
#  '.Encrypted']

# %%
#this is the path where we will clone the repo (I have already created the dir "colab_repos", but you can select your own path)
gdrive_path="MyDrive/colab_repos/"

# %%
#cd into the above path
os.chdir(f"{mount_point}{gdrive_path}") #= cd /content/gdrive/MyDrive/colab_repos/

# %%
#check above
# !pwd
# Out:
# /content/gdrive/MyDrive/colab_repos

# %%
#clone the repo
# !git clone https://github.com/JeancarloFU/paper_Efficient_Deep_Learning_Surrogate_Method_For_Lagrangian_Transport.git
# Out:
# Cloning into 'paper_Efficient_Deep_Learning_Surrogate_Method_For_Lagrangian_Transport'...
# remote: Enumerating objects: 48, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 48 (delta 15), reused 31 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (48/48), 12.93 MiB | 9.44 MiB/s, done.
# Resolving deltas: 100% (15/15), done.

# %%
#clone the repo
#!git clone https://github.com/JeancarloFU/paper_Atmospherically_Driven_Seasonal_Interannual_LTTS_MultipleInlet.git

# %%
#check the repo
# !ls
# Out:
# clone_repo_using_google_colab.ipynb
# paper_Atmospherically_Driven_Seasonal_Interannual_LTTS_MultipleInlet
# paper_Efficient_Deep_Learning_Surrogate_Method_For_Lagrangian_Transport
